# %%
# !pip install great_expectations
# Out:
# Collecting great_expectations
#   Downloading great_expectations-0.15.25-py3-none-any.whl (5.1 MB)
# Collecting jsonpatch>=1.22
#   Downloading jsonpatch-1.32-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: pandas>=1.1.0 in c:\users\rajza\anaconda3\lib\site-packages (from great_expectations) (1.2.4)
# Requirement already satisfied: pyparsing>=2.4 in c:\users\rajza\anaconda3\lib\site-packages (from great_expectations) (2.4.7)
# Requirement already satisfied: jsonschema>=2.5.1 in c:\users\rajza\anaconda3\lib\site-packages (from great_expectations) (3.2.0)
# Collecting termcolor>=1.1.0
#   Downloading termcolor-2.0.1-py3-none-any.whl (5.4 kB)
# Requirement already satisfied: ipywidgets>=7.5.1 in c:\users\rajza\anaconda3\lib\site-packages (from great_expectations) (7.6.3)
# Collecting pytz>=2021.3
#   Downloading pytz-2022.2.1-py2.py3-none-any.whl (500 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\rajza\anaconda3\lib\site-packages (from great_expectations) (2.8.1)
# Collecting ruamel.yaml<0.17.18,>=0.16
#   Downloading ruamel.yaml-0.17.17-py3-none-any.whl (109 kB)
# Collecting makefun<2,>=1.7.0
#   Downloading makefun-1.15.0-py2.py3-none-any.whl (22 kB)
# Collecting marshmallow<4.0.0,>=3.7.1
#   Downloading marshmallow-3.18.0-py3-none-any.whl (48 kB)
# Requirement already satisfied: nbformat>=5.0 in c:\users\rajza\anaconda3\lib\site-packages (from great_expectations) (5.1.3)
# Requirement already satisfied: mistune>=0.8.4 in c:\users\rajza\anaconda3\lib\site-packages (from great_expectations) (0.8.4)
# Requirement already satisfied: Click>=7.1.2 in c:\users\rajza\anaconda3\lib\site-packages (from great_expectations) (7.1.2)
# Requirement already satisfied: scipy>=0.19.0 in c:\users\rajza\anaconda3\lib\site-packages (from great_expectations) (1.6.2)
# Collecting notebook>=6.4.10
#   Downloading notebook-6.4.12-py3-none-any.whl (9.9 MB)
# Collecting altair<5,>=4.0.0
#   Downloading altair-4.2.0-py3-none-any.whl (812 kB)
# Requirement already satisfied: cryptography>=3.2 in c:\users\rajza\anaconda3\lib\site-packages (from great_expectations) (3.4.7)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\rajza\anaconda3\lib\site-packages (from great_expectations) (1.20.1)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in c:\users\rajza\anaconda3\lib\site-packages (from great_expectations) (1.26.4)
# Collecting tzlocal>=1.2
#   Downloading tzlocal-4.2-py3-none-any.whl (19 kB)
# Collecting typing-extensions>=3.10.0.0
#   Downloading typing_extensions-4.3.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: tqdm>=4.59.0 in c:\users\rajza\anaconda3\lib\site-packages (from great_expectations) (4.59.0)
# Requirement already satisfied: requests>=2.20 in c:\users\rajza\anaconda3\lib\site-packages (from great_expectations) (2.25.1)
# Requirement already satisfied: jinja2>=2.10 in c:\users\rajza\anaconda3\lib\site-packages (from great_expectations) (2.11.3)
# Requirement already satisfied: packaging in c:\users\rajza\anaconda3\lib\site-packages (from great_expectations) (20.9)
# Requirement already satisfied: importlib-metadata>=1.7.0 in c:\users\rajza\anaconda3\lib\site-packages (from great_expectations) (3.10.0)
# Requirement already satisfied: Ipython>=7.16.3 in c:\users\rajza\anaconda3\lib\site-packages (from great_expectations) (7.22.0)
# Requirement already satisfied: colorama>=0.4.3 in c:\users\rajza\anaconda3\lib\site-packages (from great_expectations) (0.4.4)
# Requirement already satisfied: toolz in c:\users\rajza\anaconda3\lib\site-packages (from altair<5,>=4.0.0->great_expectations) (0.11.1)
# Requirement already satisfied: entrypoints in c:\users\rajza\anaconda3\lib\site-packages (from altair<5,>=4.0.0->great_expectations) (0.3)
# Requirement already satisfied: cffi>=1.12 in c:\users\rajza\anaconda3\lib\site-packages (from cryptography>=3.2->great_expectations) (1.14.5)
# Requirement already satisfied: pycparser in c:\users\rajza\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=3.2->great_expectations) (2.20)
# Requirement already satisfied: zipp>=0.5 in c:\users\rajza\anaconda3\lib\site-packages (from importlib-metadata>=1.7.0->great_expectations) (3.4.1)
# Requirement already satisfied: backcall in c:\users\rajza\anaconda3\lib\site-packages (from Ipython>=7.16.3->great_expectations) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\rajza\anaconda3\lib\site-packages (from Ipython>=7.16.3->great_expectations) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in c:\users\rajza\anaconda3\lib\site-packages (from Ipython>=7.16.3->great_expectations) (5.0.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\rajza\anaconda3\lib\site-packages (from Ipython>=7.16.3->great_expectations) (3.0.17)
# Requirement already satisfied: decorator in c:\users\rajza\anaconda3\lib\site-packages (from Ipython>=7.16.3->great_expectations) (5.0.6)
# Requirement already satisfied: pygments in c:\users\rajza\anaconda3\lib\site-packages (from Ipython>=7.16.3->great_expectations) (2.8.1)
# Requirement already satisfied: setuptools>=18.5 in c:\users\rajza\anaconda3\lib\site-packages (from Ipython>=7.16.3->great_expectations) (52.0.0.post20210125)
# Requirement already satisfied: jedi>=0.16 in c:\users\rajza\anaconda3\lib\site-packages (from Ipython>=7.16.3->great_expectations) (0.17.2)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\rajza\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->great_expectations) (5.3.4)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\rajza\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->great_expectations) (3.5.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\rajza\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->great_expectations) (1.0.0)
# Requirement already satisfied: tornado>=4.2 in c:\users\rajza\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->great_expectations) (6.1)
# Requirement already satisfied: jupyter-client in c:\users\rajza\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->great_expectations) (6.1.12)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\rajza\anaconda3\lib\site-packages (from jedi>=0.16->Ipython>=7.16.3->great_expectations) (0.7.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\rajza\anaconda3\lib\site-packages (from jinja2>=2.10->great_expectations) (1.1.1)
# Collecting jsonpointer>=1.9
#   Downloading jsonpointer-2.3-py2.py3-none-any.whl (7.8 kB)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\rajza\anaconda3\lib\site-packages (from jsonschema>=2.5.1->great_expectations) (0.17.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\rajza\anaconda3\lib\site-packages (from jsonschema>=2.5.1->great_expectations) (20.3.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\rajza\anaconda3\lib\site-packages (from jsonschema>=2.5.1->great_expectations) (1.15.0)
# Requirement already satisfied: ipython-genutils in c:\users\rajza\anaconda3\lib\site-packages (from nbformat>=5.0->great_expectations) (0.2.0)
# Requirement already satisfied: jupyter-core in c:\users\rajza\anaconda3\lib\site-packages (from nbformat>=5.0->great_expectations) (4.7.1)
# Requirement already satisfied: nest-asyncio>=1.5 in c:\users\rajza\anaconda3\lib\site-packages (from notebook>=6.4.10->great_expectations) (1.5.1)
# Requirement already satisfied: prometheus-client in c:\users\rajza\anaconda3\lib\site-packages (from notebook>=6.4.10->great_expectations) (0.10.1)
# Requirement already satisfied: pyzmq>=17 in c:\users\rajza\anaconda3\lib\site-packages (from notebook>=6.4.10->great_expectations) (20.0.0)
# Collecting Send2Trash>=1.8.0
#   Downloading Send2Trash-1.8.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\rajza\anaconda3\lib\site-packages (from notebook>=6.4.10->great_expectations) (0.9.4)
# Requirement already satisfied: argon2-cffi in c:\users\rajza\anaconda3\lib\site-packages (from notebook>=6.4.10->great_expectations) (20.1.0)
# Requirement already satisfied: nbconvert>=5 in c:\users\rajza\anaconda3\lib\site-packages (from notebook>=6.4.10->great_expectations) (6.0.7)
# Requirement already satisfied: pywin32>=1.0 in c:\users\rajza\anaconda3\lib\site-packages (from jupyter-core->nbformat>=5.0->great_expectations) (227)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\rajza\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations) (0.5.3)
# Requirement already satisfied: bleach in c:\users\rajza\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations) (3.3.0)
# Requirement already satisfied: defusedxml in c:\users\rajza\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\rajza\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations) (0.1.2)
# Requirement already satisfied: testpath in c:\users\rajza\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations) (0.4.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\rajza\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations) (1.4.3)
# Requirement already satisfied: async-generator in c:\users\rajza\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert>=5->notebook>=6.4.10->great_expectations) (1.10)
# Requirement already satisfied: wcwidth in c:\users\rajza\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->Ipython>=7.16.3->great_expectations) (0.2.5)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\rajza\anaconda3\lib\site-packages (from requests>=2.20->great_expectations) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rajza\anaconda3\lib\site-packages (from requests>=2.20->great_expectations) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\rajza\anaconda3\lib\site-packages (from requests>=2.20->great_expectations) (4.0.0)
# Collecting ruamel.yaml.clib>=0.1.2
#   Downloading ruamel.yaml.clib-0.2.6-cp38-cp38-win_amd64.whl (117 kB)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\rajza\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=6.4.10->great_expectations) (0.5.7)
# Collecting tzdata
#   Downloading tzdata-2022.4-py2.py3-none-any.whl (336 kB)
# Collecting pytz-deprecation-shim
#   Downloading pytz_deprecation_shim-0.1.0.post0-py2.py3-none-any.whl (15 kB)
# Collecting backports.zoneinfo
#   Downloading backports.zoneinfo-0.2.1-cp38-cp38-win_amd64.whl (38 kB)
# Requirement already satisfied: webencodings in c:\users\rajza\anaconda3\lib\site-packages (from bleach->nbconvert>=5->notebook>=6.4.10->great_expectations) (0.5.1)
# Installing collected packages: Send2Trash, tzdata, pytz, notebook, backports.zoneinfo, ruamel.yaml.clib, pytz-deprecation-shim, jsonpointer, tzlocal, typing-extensions, termcolor, ruamel.yaml, marshmallow, makefun, jsonpatch, altair, great-expectations
#   Attempting uninstall: Send2Trash
#     Found existing installation: Send2Trash 1.5.0
#     Uninstalling Send2Trash-1.5.0:
#       Successfully uninstalled Send2Trash-1.5.0
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2021.1
#     Uninstalling pytz-2021.1:
#       Successfully uninstalled pytz-2021.1
#   Attempting uninstall: notebook
#     Found existing installation: notebook 6.3.0
#     Uninstalling notebook-6.3.0:
#       Successfully uninstalled notebook-6.3.0
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.7.4.3
#     Uninstalling typing-extensions-3.7.4.3:
#       Successfully uninstalled typing-extensions-3.7.4.3
# Successfully installed Send2Trash-1.8.0 altair-4.2.0 backports.zoneinfo-0.2.1 great-expectations-0.15.25 jsonpatch-1.32 jsonpointer-2.3 makefun-1.15.0 marshmallow-3.18.0 notebook-6.4.12 pytz-2022.2.1 pytz-deprecation-shim-0.1.0.post0 ruamel.yaml-0.17.17 ruamel.yaml.clib-0.2.6 termcolor-2.0.1 typing-extensions-4.3.0 tzdata-2022.4 tzlocal-4.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.4 requires pathlib, which is not installed.

# %%
import great_expectations as ge
df = ge.read_csv('C:/Users/rajza/Documents/Portfolio Projects/Assessing  Data Quality/activities.csv')

# %%
df.head()
# Out:
# C:\Users\rajza\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    Activity ID              Activity Date                       Activity Name  \
# 0    720562793  Sep 21, 2016, 11:47:58 PM                       Afternoon Run
# 1   2223302257  Mar 18, 2019, 11:21:14 PM                   Sunny Foot Gaurds
# 2   2228322663  Mar 21, 2019, 12:00:04 AM                   Sunny gaurds foot
# 3   2261159302    Apr 3, 2019, 1:11:19 AM  Extended guard foot sunny 5k racer
# 4   2263517705    Apr 4, 2019, 1:08:02 AM                           Hill slc
#
#   Activity Type              Activity Description  Elapsed Time  Distance  \
# 0           Run                               NaN          1310      3.31
# 1           Run                               NaN          1315      3.92
# 2           Run  Wind was strong. Made it harder           1291      3.93
# 3           Run                               NaN          1555      5.09
# 4           Run                               NaN          1606      3.06
#
#    Max Heart Rate  Relative Effort  Commute  ...  Weather Ozone  \
# 0             NaN              NaN    False  ...            NaN
# 1             NaN              NaN    False  ...            NaN
# 2             NaN              NaN    False  ...            NaN
# 3             NaN              NaN    False  ...            NaN
# 4             NaN              NaN    False  ...            NaN
#
#   <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.jump_count">Jump Count</span>  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.total_grit">Total Grit</span>  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.avg_flow">Avg Flow</span>  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.flagged">Flagged</span>  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.avg_elapsed_speed">Avg Elapsed Speed</span>  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.dirt_distance">Dirt Distance</span>  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.newly_explored_distance">Newly Explored Distance</span>  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.newly_explored_dirt_distance">Newly Explored Dirt Distance</span>  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.sport_type">Sport Type</span>
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 84 columns]

# %%
# Is Activity ID unique 

df.expect_column_values_to_be_unique(column="Activity ID")
# Out:
# C:\Users\rajza\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# {
#   "result": {
#     "element_count": 423,
#     "missing_count": 0,
#     "missing_percent": 0.0,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "unexpected_percent_total": 0.0,
#     "unexpected_percent_nonmissing": 0.0,
#     "partial_unexpected_list": []
#   },
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   },
#   "meta": {},
#   "success": true
# }

# %%
# Is the activity type one of the following?
# Bike Hike Walk Run 
activities = ['Run', 'Hike', 'Walk','Bike']
df.expect_column_values_to_be_in_set('Activity Type',
        value_set = activities)
# Out:
# C:\Users\rajza\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# {
#   "result": {
#     "element_count": 423,
#     "missing_count": 0,
#     "missing_percent": 0.0,
#     "unexpected_count": 122,
#     "unexpected_percent": 28.841607565011824,
#     "unexpected_percent_total": 28.841607565011824,
#     "unexpected_percent_nonmissing": 28.841607565011824,
#     "partial_unexpected_list": [
#       "Stand Up Paddling",
#       "Stand Up Paddling",
#       "Ride",
#       "Ride",
#       "Ride",
#       "Ride",
#       "Ride",
#       "Ride",
#       "Ride",
#       "Ride",
#       "Ride",
#       "Ride",
#       "Ride",
#       "Ride",
#       "Ride",
#       "Ride",
#       "Ride",
#       "Ride",
#       "Ride",
#       "Ride"
#     ]
#   },
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   },
#   "meta": {},
#   "success": false
# }

# %%
df.expect_column_values_to_be_between('Max Speed',0,12)
# Out:
# C:\Users\rajza\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# {
#   "result": {
#     "element_count": 423,
#     "missing_count": 0,
#     "missing_percent": 0.0,
#     "unexpected_count": 43,
#     "unexpected_percent": 10.16548463356974,
#     "unexpected_percent_total": 10.16548463356974,
#     "unexpected_percent_nonmissing": 10.16548463356974,
#     "partial_unexpected_list": [
#       17.600000381469727,
#       12.5,
#       18.200000762939453,
#       17.899999618530273,
#       12.100000381469728,
#       15.800000190734863,
#       19.200000762939453,
#       13.399999618530272,
#       12.899999618530272,
#       12.300000190734863,
#       12.100000381469728,
#       34.29999923706055,
#       13.800000190734863,
#       12.199999809265137,
#       20.100000381469727,
#       31.399999618530277,
#       14.0,
#       16.700000762939453,
#       17.700000762939453,
#       13.800000190734863
#     ]
#   },
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   },
#   "meta": {},
#   "success": false
# }
